# %% [markdown]
# <div class="alert alert-info">
# <h1><strong> Rise of the OTT 📈</strong></h1>
#     </div>

# %% [markdown]
# ## The consumption of OTT platforms has increased significanlty due to the improved accessibility of web.
# #### Below, we are going to analyze customer trends and behaviors across different locations, genres and various other attributes.
# #### Post analyzing different platforms, we will have some hidden insights about the OTT platforms

# %% [markdown]
# <div>
# <img src="https://bestofsno.com/wp-content/uploads/2019/11/IMG_5463-900x600.jpg" width="330"/>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong> Let's get the necessary Imports done before the Analysis</strong></h3>
# </div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg
import math
import plotly.express as px
import plotly.graph_objects as go

from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from plotly.colors import n_colors
from plotly.subplots import make_subplots
from IPython.display import Image
from colorama import Fore, Back, Style
y_ = Fore.YELLOW
r_ = Fore.RED
g_ = Fore.GREEN
b_ = Fore.BLUE
m_ = Fore.MAGENTA
sr_ = Style.RESET_ALL

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Just alotting Custom color palette to the Top 4 OTTs which we're analysing for better Understanding of Users</strong></h3>
# </div>

# %%
custom_colors = ["#ff6b6b","#95d5b2","#a2d2ff","#72efdd"]
customPalette = sns.set_palette(sns.color_palette(custom_colors))

# %%
sns.palplot(sns.color_palette(custom_colors),size=1)

# %% [markdown]
# > <h3>Netflix</h3>

# %%
netflix_p = sns.light_palette(custom_colors[0], reverse=True)
sns.palplot(sns.color_palette(netflix_p),size=1)

# %% [markdown]
# > <h3>Hulu</h3>

# %%
hulu_p = sns.light_palette(custom_colors[1], reverse=True)
sns.palplot(sns.color_palette(hulu_p),size=1)

# %% [markdown]
# > <h3>Prime Video</h3>

# %%
prime_p = sns.light_palette(custom_colors[2], reverse=True)
sns.palplot(sns.color_palette(prime_p),size=1)

# %% [markdown]
# > <h3>Disney+</h3>

# %%
disney_p = sns.dark_palette(custom_colors[3], reverse=True)
sns.palplot(sns.color_palette(disney_p),size=1)

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Loading the dataset and displaying rows</strong></h3>
# </div>

# %%
df_tv = pd.read_csv('D:/D.A/Polestar/Data/1/tv_shows.csv')
df_movies = pd.read_csv('D:/D.A/Polestar/Data/1/movies.csv')

# %%
df_tv = df_tv.drop(['Unnamed: 0'], axis = 1) 
df_tv.head(5)
# Out:
#               Title  Year  Age  IMDb Rotten Tomatoes  Netflix  Hulu  \
# 0      Breaking Bad  2008  18+   9.5             96%        1     0
# 1   Stranger Things  2016  16+   8.8             93%        1     0
# 2       Money Heist  2017  18+   8.4             91%        1     0
# 3          Sherlock  2010  16+   9.1             78%        1     0
# 4  Better Call Saul  2015  18+   8.7             97%        1     0
#
#    Prime Video  Disney+  type
# 0            0        0     1
# 1            0        0     1
# 2            0        0     1
# 3            0        0     1
# 4            0        0     1

# %%
df_movies = df_movies.drop(['Unnamed: 0','ID'], axis = 1) 
df_movies.head(5)
# Out:
#                             Title  Year  Age  IMDb Rotten Tomatoes  Netflix  \
# 0                       Inception  2010  13+   8.8             87%        1
# 1                      The Matrix  1999  18+   8.7             87%        1
# 2          Avengers: Infinity War  2018  13+   8.5             84%        1
# 3              Back to the Future  1985   7+   8.5             96%        1
# 4  The Good, the Bad and the Ugly  1966  18+   8.8             97%        1
#
#    Hulu  Prime Video  Disney+  Type                       Directors  \
# 0     0            0        0     0               Christopher Nolan
# 1     0            0        0     0  Lana Wachowski,Lilly Wachowski
# 2     0            0        0     0         Anthony Russo,Joe Russo
# 3     0            0        0     0                 Robert Zemeckis
# 4     0            1        0     0                    Sergio Leone
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
# 3           Adventure,Comedy,Sci-Fi                 United States
# 4                           Western      Italy,Spain,West Germany
#
#                   Language  Runtime
# 0  English,Japanese,French    148.0
# 1                  English    136.0
# 2                  English    149.0
# 3                  English    116.0
# 4                  Italian    161.0

# %% [markdown]
# <h3> Number of unique directors for movies </h3>

# %%
len(df_movies['Directors'].unique())
# Out:
# 11339

# %% [markdown]
# <h3>Number of unique genres for movies </h3>

# %%
len(df_movies['Genres'].unique())
# Out:
# 1910

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Feature generation</strong></h3>
# </div>

# %%
def splitting(dataframe,col):
    result = dataframe[col].str.get_dummies(',')
    print('Done!')
    return result

# %%
m_genres = splitting(df_movies,'Genres')
m_lang = splitting(df_movies,'Language')
# Out:
# Done!
# Done!

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Market Share in terms TV Shows, Movies and Subscribers count for OTT platforms </strong></h3>
# </div>

# %%
def val_sum(df,c):
    return df[c].sum(axis=0)

# %%
val_counts = []
dfs = [df_movies,df_tv]
cols = ['Netflix','Hulu','Prime Video','Disney+']

for x in dfs:
    for y in cols:
        val_counts.append(val_sum(x,y))

# %%
val_counts
# Out:
# [3560, 903, 12354, 564, 1931, 1754, 2144, 180]

# %%
def donut(i,df,sizes,title):
    plt.subplot(i)
    plt.pie(sizes, explode=explode, labels=labels, colors=colors,
                autopct='%1.1f%%', shadow=True)

    centre_circle = plt.Circle((0,0),0.5,color='black', fc='white',linewidth=1.25)
    fig = plt.gcf()
    fig.gca().add_artist(centre_circle)
    plt.title(title)
    plt.axis('equal')

# %%
fig = plt.subplots(figsize=(16, 8))
labels = 'Netflix', 'Hulu','Prime','Disney+'
sizes1 = [val_counts[0], val_counts[1],val_counts[2],val_counts[3]]
sizes2 = [val_counts[4], val_counts[5],val_counts[6],val_counts[7]]
colors = custom_colors
explode = (0, 0, 0, 0) 

donut(121,df_movies,sizes1,'Movies')
donut(122,df_tv,sizes2,'TV shows')
plt.show()

# %% [markdown]
# <div>
# <h4><strong>📌 Prime has the maximum number of movies and TV shows!<br><br>
#     Now, let us compare the streaming services by subscribers, given in millions</strong></h4>
# </div>

# %% [markdown]
# <div>
# <img src="https://1z1euk35x7oy36s8we4dr6lo-wpengine.netdna-ssl.com/wp-content/uploads/2018/11/netflix-subs-v-rivals.png" width="770"/>
# </div>

# %% [markdown]
# <div>
#     <h4><strong>📌 Netflix comfortably has the world’s biggest streaming service.  <br><br>
#     Amazon Prime, having 150 million subscribers , becomes a distant second, whereas the relatively fresh Disney Plus reported 87 million.  </strong></h4>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Let's see the Movies on each platform with the highest IMDb rating and genres</strong></h3>
# </div>

# %%
def sunburst(dataframe,platform,c):
    dataframe=dataframe.loc[dataframe[platform] == 1]
    dataframe=dataframe.sort_values(by='IMDb', ascending=False)
    rating = dataframe[0:10]
    fig =px.sunburst(
    rating,
    path=['Title','Genres'],
    values='IMDb',
    color='IMDb',
    color_continuous_scale=c)
    fig.show()

# %%
print('Netlfix')
sunburst(df_movies,'Netflix','amp')
# Out:
# Netlfix
# <div>                            <div id="ff72f176-1bad-4190-9431-910715865ce3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff72f176-1bad-4190-9431-910715865ce3")) {                    Plotly.newPlot(                        "ff72f176-1bad-4190-9431-910715865ce3",                        [{"branchvalues": "total", "customdata": [[8.8], [8.7], [8.7], [8.7], [8.7], [8.7], [8.6], [9.1], [9.3], [8.8], [8.7], [8.7], [8.8], [8.6], [9.3], [9.1], [8.7], [8.8], [8.7], [8.7]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>IMDb_sum=%{value}<br>parent=%{parent}<br>id=%{id}<br>IMDb=%{color}<extra></extra>", "ids": ["Inception/Action,Adventure,Sci-Fi,Thriller", "The Matrix/Action,Sci-Fi", "Eh Janam Tumhare Lekhe/Biography", "Untamed Romania/Documentary", "Bill Hicks: Relentless/Documentary,Comedy", "One Heart: The A.R. Rahman Concert Film/Documentary,Music", "Merku Thodarchi Malai/Drama", "Natsamrat/Drama,Family", "My Next Guest with David Letterman and Shah Rukh Khan/Talk-Show", "The Good, the Bad and the Ugly/Western", "Bill Hicks: Relentless", "Eh Janam Tumhare Lekhe", "Inception", "Merku Thodarchi Malai", "My Next Guest with David Letterman and Shah Rukh Khan", "Natsamrat", "One Heart: The A.R. Rahman Concert Film", "The Good, the Bad and the Ugly", "The Matrix", "Untamed Romania"], "labels": ["Action,Adventure,Sci-Fi,Thriller", "Action,Sci-Fi", "Biography", "Documentary", "Documentary,Comedy", "Documentary,Music", "Drama", "Drama,Family", "Talk-Show", "Western", "Bill Hicks: Relentless", "Eh Janam Tumhare Lekhe", "Inception", "Merku Thodarchi Malai", "My Next Guest with David Letterman and Shah Rukh Khan", "Natsamrat", "One Heart: The A.R. Rahman Concert Film", "The Good, the Bad and the Ugly", "The Matrix", "Untamed Romania"], "marker": {"coloraxis": "coloraxis", "colors": [8.8, 8.7, 8.7, 8.7, 8.7, 8.7, 8.6, 9.1, 9.3, 8.8, 8.7, 8.7, 8.8, 8.6, 9.3, 9.1, 8.7, 8.8, 8.7, 8.7]}, "name": "", "parents": ["Inception", "The Matrix", "Eh Janam Tumhare Lekhe", "Untamed Romania", "Bill Hicks: Relentless", "One Heart: The A.R. Rahman Concert Film", "Merku Thodarchi Malai", "Natsamrat", "My Next Guest with David Letterman and Shah Rukh Khan", "The Good, the Bad and the Ugly", "", "", "", "", "", "", "", "", "", ""], "type": "sunburst", "values": [8.8, 8.7, 8.7, 8.7, 8.7, 8.7, 8.6, 9.1, 9.3, 8.8, 8.7, 8.7, 8.8, 8.6, 9.3, 9.1, 8.7, 8.8, 8.7, 8.7]}],                        {"coloraxis": {"colorbar": {"title": {"text": "IMDb"}}, "colorscale": [[0.0, "rgb(241, 236, 236)"], [0.09090909090909091, "rgb(230, 209, 203)"], [0.18181818181818182, "rgb(221, 182, 170)"], [0.2727272727272727, "rgb(213, 156, 137)"], [0.36363636363636365, "rgb(205, 129, 103)"], [0.45454545454545453, "rgb(196, 102, 73)"], [0.5454545454545454, "rgb(186, 74, 47)"], [0.6363636363636364, "rgb(172, 44, 36)"], [0.7272727272727273, "rgb(149, 19, 39)"], [0.8181818181818182, "rgb(120, 14, 40)"], [0.9090909090909091, "rgb(89, 13, 31)"], [1.0, "rgb(60, 9, 17)"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "col ...

# %%
print('Hulu')
sunburst(df_movies,'Hulu','Blugrn')
# Out:
# Hulu
# <div>                            <div id="cca3a730-83c4-44cb-954c-1822ddb51bb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cca3a730-83c4-44cb-954c-1822ddb51bb3")) {                    Plotly.newPlot(                        "cca3a730-83c4-44cb-954c-1822ddb51bb3",                        [{"branchvalues": "total", "customdata": [[9.0], [8.5], [8.7], [8.6], [8.6], [8.3], [8.3], [8.3], [8.2], [8.5], [8.3], [8.5], [8.3], [8.7], [8.5], [8.3], [8.6], [8.2], [9.0], [8.6]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>IMDb_sum=%{value}<br>parent=%{parent}<br>id=%{id}<br>IMDb=%{color}<extra></extra>", "ids": ["The Dark Knight/Action,Crime,Drama,Thriller", "Grave of the Fireflies/Animation,Drama,War", "GoodFellas/Biography,Crime,Drama", "Parasite/Comedy,Drama,Thriller", "The Green Mile/Crime,Drama,Fantasy,Mystery", "Andy Irons: Kissed by God/Documentary", "Larger than Life: The Kevyn Aucoin Story/Documentary", "Good Will Hunting/Drama,Romance", "Portrait of a Lady on Fire/Drama,Romance", "Brad Paisley Thinks He's Special/Music", "Andy Irons: Kissed by God", "Brad Paisley Thinks He's Special", "Good Will Hunting", "GoodFellas", "Grave of the Fireflies", "Larger than Life: The Kevyn Aucoin Story", "Parasite", "Portrait of a Lady on Fire", "The Dark Knight", "The Green Mile"], "labels": ["Action,Crime,Drama,Thriller", "Animation,Drama,War", "Biography,Crime,Drama", "Comedy,Drama,Thriller", "Crime,Drama,Fantasy,Mystery", "Documentary", "Documentary", "Drama,Romance", "Drama,Romance", "Music", "Andy Irons: Kissed by God", "Brad Paisley Thinks He's Special", "Good Will Hunting", "GoodFellas", "Grave of the Fireflies", "Larger than Life: The Kevyn Aucoin Story", "Parasite", "Portrait of a Lady on Fire", "The Dark Knight", "The Green Mile"], "marker": {"coloraxis": "coloraxis", "colors": [9.0, 8.5, 8.7, 8.6, 8.6, 8.3, 8.3, 8.3, 8.2, 8.5, 8.3, 8.5, 8.3, 8.7, 8.5, 8.3, 8.6, 8.2, 9.0, 8.6]}, "name": "", "parents": ["The Dark Knight", "Grave of the Fireflies", "GoodFellas", "Parasite", "The Green Mile", "Andy Irons: Kissed by God", "Larger than Life: The Kevyn Aucoin Story", "Good Will Hunting", "Portrait of a Lady on Fire", "Brad Paisley Thinks He's Special", "", "", "", "", "", "", "", "", "", ""], "type": "sunburst", "values": [9.0, 8.5, 8.7, 8.6, 8.6, 8.3, 8.3, 8.3, 8.2, 8.5, 8.3, 8.5, 8.3, 8.7, 8.5, 8.3, 8.6, 8.2, 9.0, 8.6]}],                        {"coloraxis": {"colorbar": {"title": {"text": "IMDb"}}, "colorscale": [[0.0, "rgb(196, 230, 195)"], [0.16666666666666666, "rgb(150, 210, 164)"], [0.3333333333333333, "rgb(109, 188, 144)"], [0.5, "rgb(77, 162, 132)"], [0.6666666666666666, "rgb(54, 135, 122)"], [0.8333333333333334, "rgb(38, 107, 110)"], [1.0, "rgb(29, 79, 96)"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.777777777777 ...

# %%
print('Prime Video')
sunburst(df_movies,'Prime Video','haline')
# Out:
# Prime Video
# <div>                            <div id="6582ff05-7686-459d-a1a9-e7f6e962d0aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6582ff05-7686-459d-a1a9-e7f6e962d0aa")) {                    Plotly.newPlot(                        "6582ff05-7686-459d-a1a9-e7f6e962d0aa",                        [{"branchvalues": "total", "customdata": [[9.3], [9.3], [9.3], [9.0], [9.1], [9.0], [9.3], [9.1], [8.9], [9.3], [9.0], [9.3], [9.3], [9.0], [9.1], [9.3], [9.3], [9.3], [8.9], [9.1]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>IMDb_sum=%{value}<br>parent=%{parent}<br>id=%{id}<br>IMDb=%{color}<extra></extra>", "ids": ["Bounty/Adventure,Drama,History,Romance", "Steven Banks: Home Entertainment Center/Comedy", "Love on a Leash/Comedy,Drama,Fantasy,Romance", "Escape from Firebase Kate/Documentary", "Where's Daddy?/Documentary", "A Dog Named Gucci/Documentary,Biography,Drama,News", "Square One/Documentary,Drama,Music", "Finding Family/Documentary,Family,History,War", "The Creators/Documentary,History,Music,News", "Down, But Not Out!/Documentary,Sport", "A Dog Named Gucci", "Bounty", "Down, But Not Out!", "Escape from Firebase Kate", "Finding Family", "Love on a Leash", "Square One", "Steven Banks: Home Entertainment Center", "The Creators", "Where's Daddy?"], "labels": ["Adventure,Drama,History,Romance", "Comedy", "Comedy,Drama,Fantasy,Romance", "Documentary", "Documentary", "Documentary,Biography,Drama,News", "Documentary,Drama,Music", "Documentary,Family,History,War", "Documentary,History,Music,News", "Documentary,Sport", "A Dog Named Gucci", "Bounty", "Down, But Not Out!", "Escape from Firebase Kate", "Finding Family", "Love on a Leash", "Square One", "Steven Banks: Home Entertainment Center", "The Creators", "Where's Daddy?"], "marker": {"coloraxis": "coloraxis", "colors": [9.3, 9.3, 9.3, 9.0, 9.1, 9.0, 9.3, 9.1, 8.9, 9.3, 9.0, 9.3, 9.3, 9.0, 9.1, 9.3, 9.3, 9.3, 8.9, 9.1]}, "name": "", "parents": ["Bounty", "Steven Banks: Home Entertainment Center", "Love on a Leash", "Escape from Firebase Kate", "Where's Daddy?", "A Dog Named Gucci", "Square One", "Finding Family", "The Creators", "Down, But Not Out!", "", "", "", "", "", "", "", "", "", ""], "type": "sunburst", "values": [9.3, 9.3, 9.3, 9.0, 9.1, 9.0, 9.3, 9.1, 8.9, 9.3, 9.0, 9.3, 9.3, 9.0, 9.1, 9.3, 9.3, 9.3, 8.9, 9.1]}],                        {"coloraxis": {"colorbar": {"title": {"text": "IMDb"}}, "colorscale": [[0.0, "rgb(41, 24, 107)"], [0.09090909090909091, "rgb(42, 35, 160)"], [0.18181818181818182, "rgb(15, 71, 153)"], [0.2727272727272727, "rgb(18, 95, 142)"], [0.36363636363636365, "rgb(38, 116, 137)"], [0.45454545454545453, "rgb(53, 136, 136)"], [0.5454545454545454, "rgb(65, 157, 133)"], [0.6363636363636364, "rgb(81, 178, 124)"], [0.7272727272727273, "rgb(111, 198, 107)"], [0.8181818181818182, "rgb(160, 214, 91)"], [0.9090909090909091, "rgb(212, 225, 112)"], [1.0, "rgb(253, 238, 153)"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0. ...

# %%
print('Disney+')
sunburst(df_movies,'Disney+','dense')
# Out:
# Disney+
# <div>                            <div id="6ca10580-aba4-4d28-bfea-7e92df816846" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ca10580-aba4-4d28-bfea-7e92df816846")) {                    Plotly.newPlot(                        "6ca10580-aba4-4d28-bfea-7e92df816846",                        [{"branchvalues": "total", "customdata": [[8.4], [8.6], [8.3], [8.7], [8.3], [8.5], [8.4], [8.4], [8.3], [8.5], [8.4], [8.3], [8.4], [8.5], [8.3], [8.6], [8.3], [8.7], [8.5], [8.4]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>IMDb_sum=%{value}<br>parent=%{parent}<br>id=%{id}<br>IMDb=%{color}<extra></extra>", "ids": ["Avengers: Endgame/Action,Adventure,Drama,Sci-Fi", "Star Wars: A New Hope/Action,Adventure,Fantasy,Sci-Fi", "Star Wars: Return of the Jedi/Action,Adventure,Fantasy,Sci-Fi", "Star Wars: The Empire Strikes Back/Action,Adventure,Fantasy,Sci-Fi", "Phineas and Ferb: Mission Marvel/Animation,Action,Comedy,Family,Musical,Sci-Fi", "The Lion King/Animation,Adventure,Drama,Family,Musical", "Coco/Animation,Adventure,Family,Fantasy,Music,Mystery", "WALL\u00b7E/Animation,Adventure,Family,Sci-Fi", "Before the Flood/Documentary", "Newsies: The Broadway Musical/Musical", "Avengers: Endgame", "Before the Flood", "Coco", "Newsies: The Broadway Musical", "Phineas and Ferb: Mission Marvel", "Star Wars: A New Hope", "Star Wars: Return of the Jedi", "Star Wars: The Empire Strikes Back", "The Lion King", "WALL\u00b7E"], "labels": ["Action,Adventure,Drama,Sci-Fi", "Action,Adventure,Fantasy,Sci-Fi", "Action,Adventure,Fantasy,Sci-Fi", "Action,Adventure,Fantasy,Sci-Fi", "Animation,Action,Comedy,Family,Musical,Sci-Fi", "Animation,Adventure,Drama,Family,Musical", "Animation,Adventure,Family,Fantasy,Music,Mystery", "Animation,Adventure,Family,Sci-Fi", "Documentary", "Musical", "Avengers: Endgame", "Before the Flood", "Coco", "Newsies: The Broadway Musical", "Phineas and Ferb: Mission Marvel", "Star Wars: A New Hope", "Star Wars: Return of the Jedi", "Star Wars: The Empire Strikes Back", "The Lion King", "WALL\u00b7E"], "marker": {"coloraxis": "coloraxis", "colors": [8.4, 8.6, 8.3, 8.7, 8.3, 8.5, 8.4, 8.4, 8.3, 8.5, 8.4, 8.3, 8.4, 8.5, 8.3, 8.6, 8.3, 8.7, 8.5, 8.4]}, "name": "", "parents": ["Avengers: Endgame", "Star Wars: A New Hope", "Star Wars: Return of the Jedi", "Star Wars: The Empire Strikes Back", "Phineas and Ferb: Mission Marvel", "The Lion King", "Coco", "WALL\u00b7E", "Before the Flood", "Newsies: The Broadway Musical", "", "", "", "", "", "", "", "", "", ""], "type": "sunburst", "values": [8.4, 8.6, 8.3, 8.7, 8.3, 8.5, 8.4, 8.4, 8.3, 8.5, 8.4, 8.3, 8.4, 8.5, 8.3, 8.6, 8.3, 8.7, 8.5, 8.4]}],                        {"coloraxis": {"colorbar": {"title": {"text": "IMDb"}}, "colorscale": [[0.0, "rgb(230, 240, 240)"], [0.09090909090909091, "rgb(191, 221, 229)"], [0.18181818181818182, "rgb(156, 201, 226)"], [0.2727272727272727, "rgb(129, 180, 227)"], [0.36363636363636365, "rgb(115, 154, 228)"], [0.45454545454545453, "rgb(117, 127, 221)"], [0.5454545454545454, "rgb(120, 100, 202)"], [0.6363636363636364, "rgb(119, 74, 175)"], [0.7272727272727273, "rgb(113, 50, 141)"], [0.8181818181818182, "rgb(100, 31, 104)"], [0.9090909090909091, "rgb(80, 20, 66)"], [1.0, "rgb(54, 14, 36)"]]}, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor":  ...

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>User Analysis for OTTs</strong></h3>
# </div>

# %% [markdown]
# <div>
# <img src= "https://1z1euk35x7oy36s8we4dr6lo-wpengine.netdna-ssl.com/wp-content/uploads/2018/11/netflix-use-own-account.png" width="770"/>
# </div>

# %% [markdown]
# <div>
#     <h3><strong>With whom do Users share their accounts?</strong></h3>
# </div>

# %% [markdown]
# <div>
# <img src= "https://1z1euk35x7oy36s8we4dr6lo-wpengine.netdna-ssl.com/wp-content/uploads/2018/11/netflix-password-sharing.png" width="770"/>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Release year of movies across different platforms</strong></h3>
# </div>

# %%
post_1980 = df_movies[df_movies.Year >= 1980]
year_movies = post_1980.groupby('Year')[['Netflix','Hulu','Prime Video','Disney+']].sum()

plt.figure(figsize = (16, 8))
sns.lineplot(x=year_movies.index,y=year_movies['Netflix'])
sns.lineplot(x=year_movies.index,y=year_movies['Hulu'])
sns.lineplot(x=year_movies.index,y=year_movies['Prime Video'])
sns.lineplot(x=year_movies.index,y=year_movies['Disney+'])
plt.xlabel('Release Year', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>TV shows with minimum age requirement on each platform</strong></h3>
# </div>

# %%
df_t = df_tv.copy()
df_t = df_t[df_t['Age'].notna()]

# %%
df_t['Age']=df_t['Age'].str.replace('+','')
df_t['Age']=df_t['Age'].str.replace('all','0')
df_t['Age']=df_t['Age'].astype(str).astype(int)

# %%
def barplot(i,dataframe,platform,p):
    plt.subplot(i)
    dataframe=dataframe.loc[dataframe[platform] == 1]
    dataframe = dataframe['Age'].value_counts().reset_index()
    dataframe.columns=['age','count']
    sns.barplot(x="age", y="count", data=dataframe,palette=p)
    plt.xlabel('Age', fontsize = 15)
    plt.ylabel(platform, fontsize = 15)

# %%
plt.figure(figsize = (20, 20))

barplot(421,df_t,'Netflix',netflix_p)
barplot(423,df_t,'Hulu',hulu_p)
barplot(425,df_t,'Prime Video',prime_p)
barplot(427,df_t,'Disney+',disney_p)

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Countries with highest rated content.</strong></h3>
# </div>

# %%
import plotly.express as px
data = dict(
    number=[1063,619,135,60,44,41,40,40,38,35],
    country=["United States", "India", "United Kingdom", "Canada", "Spain",'Turkey','Philippines','France','South Korea','Australia'])
fig = px.funnel(data, x='number', y='country')
fig.show()
# Out:
# <div>                            <div id="14f7677f-f643-4374-948f-e4ea6b7e569b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14f7677f-f643-4374-948f-e4ea6b7e569b")) {                    Plotly.newPlot(                        "14f7677f-f643-4374-948f-e4ea6b7e569b",                        [{"hovertemplate": "number=%{x}<br>country=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "orientation": "h", "showlegend": false, "type": "funnel", "x": [1063, 619, 135, 60, 44, 41, 40, 40, 38, 35], "xaxis": "x", "y": ["United States", "India", "United Kingdom", "Canada", "Spain", "Turkey", "Philippines", "France", "South Korea", "Australia"], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0,  ...

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>TV shows with the highest IMDb rating vs availability</strong></h3>
# </div>

# %%
r = df_tv.sort_values(by='IMDb', ascending=False)
r = r[0:20]
r = r[['Title','IMDb','Netflix','Hulu','Prime Video','Disney+']]
r.style.bar(subset=["Netflix",], color='#ff6b6b')\
                 .bar(subset=["Hulu"], color='#95d5b2')\
                 .bar(subset=["Prime Video"], color='#a2d2ff')\
                 .bar(subset=["Disney+"], color='#72efdd')\
                 .bar(subset=["IMDb"],color='#').background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,# 100.0%, transparent 100.0%);
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow0_col2 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 100.0%, transparent 100.0%);
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow0_col4 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow0_col5 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,# 80.0%, transparent 80.0%);
#             background-color:  #61409b;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 100.0%, transparent 100.0%);
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow1_col3 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow1_col4 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow1_col5 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,# 80.0%, transparent 80.0%);
#             background-color:  #61409b;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow2_col2 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow2_col3 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 100.0%, transparent 100.0%);
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow2_col5 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,# 80.0%, transparent 80.0%);
#             background-color:  #61409b;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow3_col2 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 100.0%, transparent 100.0%);
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow3_col4 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow3_col5 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,# 60.0%, transparent 60.0%);
#             background-color:  #8683bd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow4_col2 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow4_col3 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 100.0%, transparent 100.0%);
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow4_col5 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,# 60.0%, transparent 60.0%);
#             background-color:  #8683bd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow5_col2 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 100.0%, transparent 100.0%);
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 100.0%, transparent 100.0%);
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow5_col5 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,# 40.0%, transparent 40.0%);
#             background-color:  #b6b6d8;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow6_col2 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow6_col3 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 100.0%, transparent 100.0%);
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow6_col5 {
#             width:  10em;
#              height:  80%;
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_fa36cb9e_9af0_11eb_91ea_342eb797d14frow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,# 40.0%, transparent 40.0%);
#             background-color:  #b6b6d8;
#             color:  #000000;

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Analysis and Comparison of Movies of all platforms in terms of Languages and Genres</strong></h3>
# </div>

# %%
df_l_merged = pd.concat([df_movies, m_lang], axis = 1, sort = False)
df_g_merged = pd.concat([df_movies, m_genres], axis = 1, sort = False)

# %%
def bar(dataframe,platform,c):
    dataframe=dataframe.loc[dataframe[platform] == 1]
    val_counts = dataframe.iloc[:,15:].sum(axis=0).sort_values(ascending=False)
    val_counts2 = pd.DataFrame(val_counts,columns=['Number of movies'])
    return val_counts2[0:20].style.bar(subset=["Number of movies",], color=c)

# %% [markdown]
# <div>
# <img src="https://download.logo.wine/logo/Netflix/Netflix-Logo.wine.png" width="250"/>
# </div>

# %%
bar(df_l_merged,'Netflix','#ff6b6b')
# Out:
# <style  type="text/css" >
#     #T_fab5e561_9af0_11eb_905e_342eb797d14frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 100.0%, transparent 100.0%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 15.3%, transparent 15.3%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 13.3%, transparent 13.3%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 7.9%, transparent 7.9%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 3.1%, transparent 3.1%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 2.5%, transparent 2.5%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 2.4%, transparent 2.4%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 2.1%, transparent 2.1%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 1.4%, transparent 1.4%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 1.0%, transparent 1.0%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.9%, transparent 0.9%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.8%, transparent 0.8%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.7%, transparent 0.7%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.5%, transparent 0.5%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.4%, transparent 0.4%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.3%, transparent 0.3%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.3%, transparent 0.3%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.2%, transparent 0.2%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.1%, transparent 0.1%);
#         }    #T_fab5e561_9af0_11eb_905e_342eb797d14frow19_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_fab5e561_9af0_11eb_905e_342eb797d14f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of movies</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row0" class="row_heading level0 row0" >English</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow0_col0" class="data row0 col0" >2264</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row1" class="row_heading level0 row1" >Hindi</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow1_col0" class="data row1 col0" >377</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row2" class="row_heading level0 row2" >Spanish</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow2_col0" class="data row2 col0" >332</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row3" class="row_heading level0 row3" >French</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow3_col0" class="data row3 col0" >212</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row4" class="row_heading level0 row4" >German</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow4_col0" class="data row4 col0" >106</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row5" class="row_heading level0 row5" >Japanese</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow5_col0" class="data row5 col0" >91</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row6" class="row_heading level0 row6" >Arabic</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow6_col0" class="data row6 col0" >89</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row7" class="row_heading level0 row7" >Mandarin</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow7_col0" class="data row7 col0" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row8" class="row_heading level0 row8" >Italian</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow8_col0" class="data row8 col0" >67</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row9" class="row_heading level0 row9" >Turkish</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow9_col0" class="data row9 col0" >58</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row10" class="row_heading level0 row10" >Cantonese</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow10_col0" class="data row10 col0" >56</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row11" class="row_heading level0 row11" >Russian</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow11_col0" class="data row11 col0" >54</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row12" class="row_heading level0 row12" >Tamil</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow12_col0" class="data row12 col0" >52</td>
#             </tr>
#             <tr>
#                         <th id="T_fab5e561_9af0_11eb_905e_342eb797d14flevel0_row13" class="row_heading level0 row13" >Punjabi</th>
#                         <td id="T_fab5e561_9af0_11eb_905e_342eb797d14frow13_col0" class="data row13 col0" >47</td>

# %%
bar(df_g_merged,'Netflix','#ff6b6b')
# Out:
# <style  type="text/css" >
#     #T_facdf624_9af0_11eb_bde8_342eb797d14frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 100.0%, transparent 100.0%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 86.4%, transparent 86.4%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 40.0%, transparent 40.0%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 32.8%, transparent 32.8%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 32.4%, transparent 32.4%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 30.0%, transparent 30.0%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 20.2%, transparent 20.2%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 16.3%, transparent 16.3%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 16.1%, transparent 16.1%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 12.7%, transparent 12.7%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 12.1%, transparent 12.1%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 11.7%, transparent 11.7%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 9.5%, transparent 9.5%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 7.9%, transparent 7.9%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 7.6%, transparent 7.6%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 3.2%, transparent 3.2%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 3.2%, transparent 3.2%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 1.6%, transparent 1.6%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff6b6b 0.8%, transparent 0.8%);
#         }    #T_facdf624_9af0_11eb_bde8_342eb797d14frow19_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_facdf624_9af0_11eb_bde8_342eb797d14f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of movies</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row0" class="row_heading level0 row0" >Drama</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow0_col0" class="data row0 col0" >1501</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row1" class="row_heading level0 row1" >Comedy</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow1_col0" class="data row1 col0" >1308</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row2" class="row_heading level0 row2" >Thriller</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow2_col0" class="data row2 col0" >652</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row3" class="row_heading level0 row3" >Romance</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow3_col0" class="data row3 col0" >551</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row4" class="row_heading level0 row4" >Action</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow4_col0" class="data row4 col0" >545</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row5" class="row_heading level0 row5" >Documentary</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow5_col0" class="data row5 col0" >511</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row6" class="row_heading level0 row6" >Crime</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow6_col0" class="data row6 col0" >372</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row7" class="row_heading level0 row7" >Adventure</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow7_col0" class="data row7 col0" >318</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row8" class="row_heading level0 row8" >Family</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow8_col0" class="data row8 col0" >315</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row9" class="row_heading level0 row9" >Horror</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow9_col0" class="data row9 col0" >266</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row10" class="row_heading level0 row10" >Fantasy</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow10_col0" class="data row10 col0" >258</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row11" class="row_heading level0 row11" >Mystery</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow11_col0" class="data row11 col0" >252</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row12" class="row_heading level0 row12" >Animation</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow12_col0" class="data row12 col0" >222</td>
#             </tr>
#             <tr>
#                         <th id="T_facdf624_9af0_11eb_bde8_342eb797d14flevel0_row13" class="row_heading level0 row13" >Biography</th>
#                         <td id="T_facdf624_9af0_11eb_bde8_342eb797d14frow13_col0" class="d

# %% [markdown]
# <div>
# <img src=" https://s3.amazonaws.com/inside-the-brand-stage/wp-content/uploads/2019/01/HULU-1000x331.png" width="250"/>
# </div>

# %%
bar(df_l_merged,'Hulu','#95d5b2')
# Out:
# <style  type="text/css" >
#     #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 100.0%, transparent 100.0%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 8.5%, transparent 8.5%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 7.6%, transparent 7.6%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 4.6%, transparent 4.6%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 3.8%, transparent 3.8%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 2.3%, transparent 2.3%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 1.7%, transparent 1.7%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 1.6%, transparent 1.6%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 1.5%, transparent 1.5%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 1.1%, transparent 1.1%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 1.0%, transparent 1.0%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 0.9%, transparent 0.9%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 0.7%, transparent 0.7%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 0.5%, transparent 0.5%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 0.2%, transparent 0.2%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 0.1%, transparent 0.1%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 0.1%, transparent 0.1%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 0.1%, transparent 0.1%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 0.1%, transparent 0.1%);
#         }    #T_fb0619a3_9af0_11eb_91a4_342eb797d14frow19_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_fb0619a3_9af0_11eb_91a4_342eb797d14f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of movies</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row0" class="row_heading level0 row0" >English</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow0_col0" class="data row0 col0" >815</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row1" class="row_heading level0 row1" >French</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow1_col0" class="data row1 col0" >73</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row2" class="row_heading level0 row2" >Spanish</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow2_col0" class="data row2 col0" >66</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row3" class="row_heading level0 row3" >German</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow3_col0" class="data row3 col0" >41</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row4" class="row_heading level0 row4" >Japanese</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow4_col0" class="data row4 col0" >35</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row5" class="row_heading level0 row5" >Italian</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow5_col0" class="data row5 col0" >23</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row6" class="row_heading level0 row6" >Russian</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow6_col0" class="data row6 col0" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row7" class="row_heading level0 row7" >Mandarin</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow7_col0" class="data row7 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row8" class="row_heading level0 row8" >Korean</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow8_col0" class="data row8 col0" >16</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row9" class="row_heading level0 row9" >Danish</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow9_col0" class="data row9 col0" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row10" class="row_heading level0 row10" >Arabic</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow10_col0" class="data row10 col0" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row11" class="row_heading level0 row11" >Swedish</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow11_col0" class="data row11 col0" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row12" class="row_heading level0 row12" >Chinese</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow12_col0" class="data row12 col0" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_fb0619a3_9af0_11eb_91a4_342eb797d14flevel0_row13" class="row_heading level0 row13" >Latin</th>
#                         <td id="T_fb0619a3_9af0_11eb_91a4_342eb797d14frow13_col0" class="data row13 col0" >8</td>
#             </tr>

# %%
bar(df_g_merged,'Hulu','#95d5b2')
# Out:
# <style  type="text/css" >
#     #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 100.0%, transparent 100.0%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 59.8%, transparent 59.8%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 47.5%, transparent 47.5%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 30.5%, transparent 30.5%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 25.9%, transparent 25.9%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 25.2%, transparent 25.2%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 24.0%, transparent 24.0%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 20.8%, transparent 20.8%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 19.4%, transparent 19.4%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 18.2%, transparent 18.2%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 14.8%, transparent 14.8%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 14.8%, transparent 14.8%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 12.6%, transparent 12.6%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 12.1%, transparent 12.1%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 8.0%, transparent 8.0%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 3.1%, transparent 3.1%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 2.7%, transparent 2.7%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#95d5b2 0.5%, transparent 0.5%);
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow18_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_fb23be32_9af0_11eb_8b8b_342eb797d14frow19_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_fb23be32_9af0_11eb_8b8b_342eb797d14f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of movies</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row0" class="row_heading level0 row0" >Drama</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow0_col0" class="data row0 col0" >438</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row1" class="row_heading level0 row1" >Comedy</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow1_col0" class="data row1 col0" >272</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row2" class="row_heading level0 row2" >Thriller</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow2_col0" class="data row2 col0" >221</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row3" class="row_heading level0 row3" >Romance</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow3_col0" class="data row3 col0" >151</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row4" class="row_heading level0 row4" >Documentary</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow4_col0" class="data row4 col0" >132</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row5" class="row_heading level0 row5" >Action</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow5_col0" class="data row5 col0" >129</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row6" class="row_heading level0 row6" >Horror</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow6_col0" class="data row6 col0" >124</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row7" class="row_heading level0 row7" >Adventure</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow7_col0" class="data row7 col0" >111</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row8" class="row_heading level0 row8" >Family</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow8_col0" class="data row8 col0" >105</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row9" class="row_heading level0 row9" >Crime</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow9_col0" class="data row9 col0" >100</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row10" class="row_heading level0 row10" >Sci-Fi</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow10_col0" class="data row10 col0" >86</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row11" class="row_heading level0 row11" >Mystery</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow11_col0" class="data row11 col0" >86</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row12" class="row_heading level0 row12" >Fantasy</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow12_col0" class="data row12 col0" >77</td>
#             </tr>
#             <tr>
#                         <th id="T_fb23be32_9af0_11eb_8b8b_342eb797d14flevel0_row13" class="row_heading level0 row13" >Animation</th>
#                         <td id="T_fb23be32_9af0_11eb_8b8b_342eb797d14frow13_col0" class="data row13 col0" >75</td>
#             </tr>
#             <tr>

# %% [markdown]
# <div>
#
# <img src=" https://logodownload.org/wp-content/uploads/2018/07/prime-video.png" width="250"/>
# </div>

# %%
bar(df_l_merged,'Prime Video','#a2d2ff')
# Out:
# <style  type="text/css" >
#     #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 100.0%, transparent 100.0%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 4.8%, transparent 4.8%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 4.5%, transparent 4.5%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 3.8%, transparent 3.8%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 3.1%, transparent 3.1%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 3.0%, transparent 3.0%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 2.2%, transparent 2.2%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 1.5%, transparent 1.5%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 1.1%, transparent 1.1%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.8%, transparent 0.8%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.8%, transparent 0.8%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.7%, transparent 0.7%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.5%, transparent 0.5%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.5%, transparent 0.5%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.2%, transparent 0.2%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.2%, transparent 0.2%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.1%, transparent 0.1%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.0%, transparent 0.0%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.0%, transparent 0.0%);
#         }    #T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow19_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of movies</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row0" class="row_heading level0 row0" >English</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow0_col0" class="data row0 col0" >10088</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row1" class="row_heading level0 row1" >French</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow1_col0" class="data row1 col0" >522</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row2" class="row_heading level0 row2" >Spanish</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow2_col0" class="data row2 col0" >493</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row3" class="row_heading level0 row3" >Hindi</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow3_col0" class="data row3 col0" >424</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row4" class="row_heading level0 row4" >Italian</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow4_col0" class="data row4 col0" >352</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row5" class="row_heading level0 row5" >German</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow5_col0" class="data row5 col0" >341</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row6" class="row_heading level0 row6" >Mandarin</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow6_col0" class="data row6 col0" >268</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row7" class="row_heading level0 row7" >Japanese</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow7_col0" class="data row7 col0" >195</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row8" class="row_heading level0 row8" >Russian</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow8_col0" class="data row8 col0" >157</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row9" class="row_heading level0 row9" >Cantonese</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow9_col0" class="data row9 col0" >127</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row10" class="row_heading level0 row10" >Korean</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow10_col0" class="data row10 col0" >126</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row11" class="row_heading level0 row11" >Tamil</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow11_col0" class="data row11 col0" >113</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row12" class="row_heading level0 row12" >Telugu</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow12_col0" class="data row12 col0" >92</td>
#             </tr>
#             <tr>
#                         <th id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14flevel0_row13" class="row_heading level0 row13" >Arabic</th>
#                         <td id="T_fb63ca21_9af0_11eb_9ec4_342eb797d14frow13_col0" class="data row13 col0" >90</td>

# %%
bar(df_g_merged,'Prime Video','#a2d2ff')
# Out:
# <style  type="text/css" >
#     #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 100.0%, transparent 100.0%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 53.0%, transparent 53.0%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 45.8%, transparent 45.8%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 34.5%, transparent 34.5%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 31.6%, transparent 31.6%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 31.2%, transparent 31.2%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 27.6%, transparent 27.6%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 22.4%, transparent 22.4%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 17.5%, transparent 17.5%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 13.9%, transparent 13.9%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 12.5%, transparent 12.5%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 8.9%, transparent 8.9%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 7.2%, transparent 7.2%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 5.9%, transparent 5.9%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 5.6%, transparent 5.6%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 4.3%, transparent 4.3%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 3.6%, transparent 3.6%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 3.6%, transparent 3.6%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a2d2ff 0.7%, transparent 0.7%);
#         }    #T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow19_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of movies</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row0" class="row_heading level0 row0" >Drama</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow0_col0" class="data row0 col0" >5437</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row1" class="row_heading level0 row1" >Comedy</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow1_col0" class="data row1 col0" >3004</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row2" class="row_heading level0 row2" >Thriller</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow2_col0" class="data row2 col0" >2632</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row3" class="row_heading level0 row3" >Action</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow3_col0" class="data row3 col0" >2049</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row4" class="row_heading level0 row4" >Documentary</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow4_col0" class="data row4 col0" >1895</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row5" class="row_heading level0 row5" >Horror</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow5_col0" class="data row5 col0" >1878</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row6" class="row_heading level0 row6" >Romance</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow6_col0" class="data row6 col0" >1691</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row7" class="row_heading level0 row7" >Crime</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow7_col0" class="data row7 col0" >1423</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row8" class="row_heading level0 row8" >Adventure</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow8_col0" class="data row8 col0" >1166</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row9" class="row_heading level0 row9" >Mystery</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow9_col0" class="data row9 col0" >983</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row10" class="row_heading level0 row10" >Sci-Fi</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow10_col0" class="data row10 col0" >907</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row11" class="row_heading level0 row11" >Family</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow11_col0" class="data row11 col0" >721</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row12" class="row_heading level0 row12" >Fantasy</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow12_col0" class="data row12 col0" >635</td>
#             </tr>
#             <tr>
#                         <th id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14flevel0_row13" class="row_heading level0 row13" >Biography</th>
#                         <td id="T_fb7ecdde_9af0_11eb_ab71_342eb797d14frow13_col0" class=

# %% [markdown]
# <div>
# <img src=" https://download.logo.wine/logo/Disney%2B/Disney%2B-Logo.wine.png" width="250"/>
# </div>

# %%
bar(df_l_merged,'Disney+','#72efdd')
# Out:
# <style  type="text/css" >
#     #T_fbb84801_9af0_11eb_9772_342eb797d14frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 100.0%, transparent 100.0%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 5.0%, transparent 5.0%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 3.2%, transparent 3.2%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 2.7%, transparent 2.7%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 1.6%, transparent 1.6%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.9%, transparent 0.9%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.7%, transparent 0.7%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.4%, transparent 0.4%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.4%, transparent 0.4%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.4%, transparent 0.4%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.2%, transparent 0.2%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.2%, transparent 0.2%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.2%, transparent 0.2%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.2%, transparent 0.2%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.2%, transparent 0.2%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.2%, transparent 0.2%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.2%, transparent 0.2%);
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow17_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow18_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_fbb84801_9af0_11eb_9772_342eb797d14frow19_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_fbb84801_9af0_11eb_9772_342eb797d14f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of movies</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row0" class="row_heading level0 row0" >English</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow0_col0" class="data row0 col0" >557</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row1" class="row_heading level0 row1" >French</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow1_col0" class="data row1 col0" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row2" class="row_heading level0 row2" >Spanish</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow2_col0" class="data row2 col0" >20</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row3" class="row_heading level0 row3" >German</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow3_col0" class="data row3 col0" >17</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row4" class="row_heading level0 row4" >Italian</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow4_col0" class="data row4 col0" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row5" class="row_heading level0 row5" >Mandarin</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow5_col0" class="data row5 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row6" class="row_heading level0 row6" >Japanese</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow6_col0" class="data row6 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row7" class="row_heading level0 row7" >Xhosa</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow7_col0" class="data row7 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row8" class="row_heading level0 row8" >Russian</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow8_col0" class="data row8 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row9" class="row_heading level0 row9" >Korean</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow9_col0" class="data row9 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row10" class="row_heading level0 row10" >Greek</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow10_col0" class="data row10 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row11" class="row_heading level0 row11" >Cantonese</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow11_col0" class="data row11 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row12" class="row_heading level0 row12" >Norwegian</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow12_col0" class="data row12 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row13" class="row_heading level0 row13" >Brazilian Sign Language</th>
#                         <td id="T_fbb84801_9af0_11eb_9772_342eb797d14frow13_col0" class="data row13 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_fbb84801_9af0_11eb_9772_342eb797d14flevel0_row14" class="row_heading level0 row14" >Arabic</th>

# %%
bar(df_g_merged,'Disney+','#72efdd')
# Out:
# <style  type="text/css" >
#     #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 100.0%, transparent 100.0%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 64.0%, transparent 64.0%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 58.5%, transparent 58.5%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 38.6%, transparent 38.6%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 35.3%, transparent 35.3%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 31.4%, transparent 31.4%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 17.4%, transparent 17.4%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 17.4%, transparent 17.4%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 16.4%, transparent 16.4%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 15.0%, transparent 15.0%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 11.4%, transparent 11.4%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 5.6%, transparent 5.6%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 4.1%, transparent 4.1%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 1.9%, transparent 1.9%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 1.7%, transparent 1.7%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 1.2%, transparent 1.2%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#72efdd 0.5%, transparent 0.5%);
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow17_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow18_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_fbd7fd83_9af0_11eb_9513_342eb797d14frow19_col0 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_fbd7fd83_9af0_11eb_9513_342eb797d14f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of movies</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row0" class="row_heading level0 row0" >Family</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow0_col0" class="data row0 col0" >430</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row1" class="row_heading level0 row1" >Comedy</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow1_col0" class="data row1 col0" >281</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row2" class="row_heading level0 row2" >Adventure</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow2_col0" class="data row2 col0" >258</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row3" class="row_heading level0 row3" >Fantasy</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow3_col0" class="data row3 col0" >176</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row4" class="row_heading level0 row4" >Drama</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow4_col0" class="data row4 col0" >162</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row5" class="row_heading level0 row5" >Animation</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow5_col0" class="data row5 col0" >146</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row6" class="row_heading level0 row6" >Action</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow6_col0" class="data row6 col0" >88</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row7" class="row_heading level0 row7" >Sci-Fi</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow7_col0" class="data row7 col0" >88</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row8" class="row_heading level0 row8" >Musical</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow8_col0" class="data row8 col0" >84</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row9" class="row_heading level0 row9" >Romance</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow9_col0" class="data row9 col0" >78</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row10" class="row_heading level0 row10" >Documentary</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow10_col0" class="data row10 col0" >63</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row11" class="row_heading level0 row11" >Sport</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow11_col0" class="data row11 col0" >39</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row12" class="row_heading level0 row12" >Music</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow12_col0" class="data row12 col0" >33</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row13" class="row_heading level0 row13" >Crime</th>
#                         <td id="T_fbd7fd83_9af0_11eb_9513_342eb797d14frow13_col0" class="data row13 col0" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_fbd7fd83_9af0_11eb_9513_342eb797d14flevel0_row14" class="row_heading level0 row14" >

# %% [markdown]
# <div>
# <h3><strong>Viewing hours by genre, April 2020</strong></h3>
# </div>

# %% [markdown]
# <div>
# <img src="https://1z1euk35x7oy36s8we4dr6lo-wpengine.netdna-ssl.com/wp-content/uploads/2018/11/netflix-uk-viewing-by-genre-20.png" width="450"/>
# </div>

# %% [markdown]
# ## The chart below clearly denotes the domination of Netflix as compared to other platforms

# %% [markdown]
# <div>
# <img src="https://1z1euk35x7oy36s8we4dr6lo-wpengine.netdna-ssl.com/wp-content/uploads/2018/11/netflix-orginal-demand-share.png" width="550"/>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h3><strong>Now, let us specifically analyse Netlfix</strong></h3>
# </div>

# %%
import numpy as np 
import pandas as pd
# Importing libs
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, AffinityPropagation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import plotly as py
import plotly.graph_objs as go
import os
py.offline.init_notebook_mode(connected = True)
#print(os.listdir("../input"))
import datetime as dt
import missingno as msno
plt.rcParams['figure.dpi'] = 140
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('D:/D.A/Polestar/Data/2/netflix_titles.csv')

df.head(5)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
# Missing data

for i in df.columns:
    null_rate = df[i].isna().sum() / len(df) * 100 
    if null_rate > 0 :
        print("{} null rate: {}%".format(i,round(null_rate,2)))
# Out:
# director null rate: 30.68%
# cast null rate: 9.22%
# country null rate: 6.51%
# date_added null rate: 0.13%
# rating null rate: 0.09%

# %% [markdown]
# # Dealing with the missing data

# %%
# Replacments

df['country'] = df['country'].fillna(df['country'].mode()[0])


df['cast'].replace(np.nan, 'No Data',inplace  = True)
df['director'].replace(np.nan, 'No Data',inplace  = True)

# Drops

df.dropna(inplace=True)

# Drop Duplicates

df.drop_duplicates(inplace= True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7770 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7770 non-null   object
#  1   type          7770 non-null   object
#  2   title         7770 non-null   object
#  3   director      7770 non-null   object
#  4   cast          7770 non-null   object
#  5   country       7770 non-null   object
#  6   date_added    7770 non-null   object
#  7   release_year  7770 non-null   int64
#  8   rating        7770 non-null   object
#  9   duration      7770 non-null   object
#  10  listed_in     7770 non-null   object
#  11  description   7770 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 789.1+ KB

# %% [markdown]
# # Missing values are dealt with, now we'll format the date

# %%
df["date_added"] = pd.to_datetime(df['date_added'])

df['month_added']=df['date_added'].dt.month
df['month_name_added']=df['date_added'].dt.month_name()
df['year_added'] = df['date_added'].dt.year

df.head(5)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%            No Data
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   date_added  release_year rating   duration  \
# 0 2020-08-14          2020  TV-MA  4 Seasons
# 1 2016-12-23          2016  TV-MA     93 min
# 2 2018-12-20          2011      R     78 min
# 3 2017-11-16          2009  PG-13     80 min
# 4 2020-01-01          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description  month_added  \
# 0  In a future where the elite inhabit an island ...            8
# 1  After a devastating earthquake hits Mexico Cit...           12
# 2  When an army recruit is found dead, his fellow...           12
# 3  In a postapocalyptic world, rag-doll robots hi...           11
# 4  A brilliant group of students become card-coun...            1
#
#   month_name_added  year_added
# 0           August        2020
# 1         December        2016
# 2         December        2018
# 3         November        2017
# 4          January        2020

# %%
# Palette
sns.palplot(['#221f1f', '#b20710', '#e50914','#f5f5f1'])

plt.title("Netflix brand palette ",loc='left',fontfamily='serif',fontsize=15,y=1.2)
plt.show()

# %% [markdown]
# # Content - Let's explore
#
# Now we've seen how Netflix has been dominating the OTT, let's have a look at the content they offer:)

# %%
# For viz: Ratio of Movies & TV shows

x=df.groupby(['type'])['type'].count()
y=len(df)
r=((x/y)).round(2)

mf_ratio = pd.DataFrame(r).T

# %%
fig, ax = plt.subplots(1,1,figsize=(6.5, 2.5))

ax.barh(mf_ratio.index, mf_ratio['Movie'], 
        color='#b20710', alpha=0.9, label='Male')
ax.barh(mf_ratio.index, mf_ratio['TV Show'], left=mf_ratio['Movie'], 
        color='#221f1f', alpha=0.9, label='Female')

ax.set_xlim(0, 1)
ax.set_xticks([])
ax.set_yticks([])
#ax.set_yticklabels(mf_ratio.index, fontfamily='serif', fontsize=11)


# movie percentage
for i in mf_ratio.index:
    ax.annotate(f"{int(mf_ratio['Movie'][i]*100)}%", 
                   xy=(mf_ratio['Movie'][i]/2, i),
                   va = 'center', ha='center',fontsize=40, fontweight='light', fontfamily='serif',
                   color='white')

    ax.annotate("Movie", 
                   xy=(mf_ratio['Movie'][i]/2, -0.25),
                   va = 'center', ha='center',fontsize=15, fontweight='light', fontfamily='serif',
                   color='white')
    
    
for i in mf_ratio.index:
    ax.annotate(f"{int(mf_ratio['TV Show'][i]*100)}%", 
                   xy=(mf_ratio['Movie'][i]+mf_ratio['TV Show'][i]/2, i),
                   va = 'center', ha='center',fontsize=40, fontweight='light', fontfamily='serif',
                   color='white')
    ax.annotate("TV Show", 
                   xy=(mf_ratio['Movie'][i]+mf_ratio['TV Show'][i]/2, -0.25),
                   va = 'center', ha='center',fontsize=15, fontweight='light', fontfamily='serif',
                   color='white')






# Title & Subtitle
fig.text(0.125,1.03,'Movie vs TV Show distribution', fontfamily='serif',fontsize=15, fontweight='bold')
fig.text(0.125,0.92,'We see vastly more movies than TV shows on Netflix.',fontfamily='serif',fontsize=12)  

for s in ['top', 'left', 'right', 'bottom']:
    ax.spines[s].set_visible(False)
    


#ax.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.06))

# Removing legend due to labelled plot
ax.legend().set_visible(False)
plt.show()

# %% [markdown]
# # By Country
#
# So we now know there are much more movies than TV shows on Netflix.
# What about if we look at content by country?
#
# I would imagine that the USA will have the most content as Netlfix is a US company.
#
# Very curious on how India will perform, Are you too?

# %%
# Quick feature engineering

# Helper column for various plots
df['count'] = 1

# Many productions have several countries listed - this will skew our results , we'll grab the first one mentioned

# Lets retrieve just the first country
df['first_country'] = df['country'].apply(lambda x: x.split(",")[0])
df['first_country'].head()

# Rating ages from this notebook: https://www.kaggle.com/andreshg/eda-beginner-to-expert-plotly (thank you!)

ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}

df['target_ages'] = df['rating'].replace(ratings_ages)
df['target_ages'].unique()

# Genre

df['genre'] = df['listed_in'].apply(lambda x :  x.replace(' ,',',').replace(', ',',').split(',')) 

# Reducing name length

df['first_country'].replace('United States', 'USA', inplace=True)
df['first_country'].replace('United Kingdom', 'UK',inplace=True)
df['first_country'].replace('South Korea', 'S. Korea',inplace=True)

# %% [markdown]
# ## Top content producers in terms of Countries

# %%
data = df.groupby('first_country')['count'].sum().sort_values(ascending=False)[:10]

# Plot

color_map = ['#f5f5f1' for _ in range(10)]
color_map[0] = color_map[1] = color_map[2] =  '#b20710' # color highlight

fig, ax = plt.subplots(1,1, figsize=(12, 6))
ax.bar(data.index, data, width=0.5, 
       edgecolor='darkgray',
       linewidth=0.6,color=color_map)

#annotations
for i in data.index:
    ax.annotate(f"{data[i]}", 
                   xy=(i, data[i] + 150), #i like to change this to roughly 5% of the highest cat
                   va = 'center', ha='center',fontweight='light', fontfamily='serif')



# Remove border from plot

for s in ['top', 'left', 'right']:
    ax.spines[s].set_visible(False)
    
# Tick labels

ax.set_xticklabels(data.index, fontfamily='serif', rotation=0)

# Title and sub-title

fig.text(0.09, 1, 'Top 10 countries on Netflix', fontsize=15, fontweight='bold', fontfamily='serif')
fig.text(0.09, 0.95, 'The three most frequent countries have been highlighted.', fontsize=12, fontweight='light', fontfamily='serif')

fig.text(1.1, 1.01, 'Insight', fontsize=15, fontweight='bold', fontfamily='serif')

fig.text(1.1, 0.67, '''
The most prolific producers of
content for Netflix are, primarily,
the USA, with India and the UK
a significant distance behind.

It makes sense that the USA produces 
the most content as, afterall, 
Netflix is a US company.
'''
         , fontsize=12, fontweight='light', fontfamily='serif')

ax.grid(axis='y', linestyle='-', alpha=0.4)   

grid_y_ticks = np.arange(0, 4000, 500) # y ticks, min, max, then step
ax.set_yticks(grid_y_ticks)
ax.set_axisbelow(True)

#Axis labels

#plt.xlabel("Country", fontsize=12, fontweight='light', fontfamily='serif',loc='left',y=-1.5)
#plt.ylabel("Count", fontsize=12, fontweight='light', fontfamily='serif')
 #plt.legend(loc='upper right')
    
# thicken the bottom line if you want to
plt.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .7)

ax.tick_params(axis='both', which='major', labelsize=12)


import matplotlib.lines as lines
l1 = lines.Line2D([1, 1], [0, 1], transform=fig.transFigure, figure=fig,color='black',lw=0.2)
fig.lines.extend([l1])

ax.tick_params(axis=u'both', which=u'both',length=0)

plt.show()

# %% [markdown]
# As predicted, the USA dominates.
#
# India gets the 2nd spot.
#
# The UK is a top contender too, but still some way behind India.
#
# How does content by country vary?

# %%
country_order = df['first_country'].value_counts()[:11].index
data_q2q3 = df[['type', 'first_country']].groupby('first_country')['type'].value_counts().unstack().loc[country_order]
data_q2q3['sum'] = data_q2q3.sum(axis=1)
data_q2q3_ratio = (data_q2q3.T / data_q2q3['sum']).T[['Movie', 'TV Show']].sort_values(by='Movie',ascending=False)[::-1]




###
fig, ax = plt.subplots(1,1,figsize=(15, 8),)

ax.barh(data_q2q3_ratio.index, data_q2q3_ratio['Movie'], 
        color='#b20710', alpha=0.8, label='Movie')
ax.barh(data_q2q3_ratio.index, data_q2q3_ratio['TV Show'], left=data_q2q3_ratio['Movie'], 
        color='#221f1f', alpha=0.8, label='TV Show')


ax.set_xlim(0, 1)
ax.set_xticks([])
ax.set_yticklabels(data_q2q3_ratio.index, fontfamily='serif', fontsize=11)

# male percentage
for i in data_q2q3_ratio.index:
    ax.annotate(f"{data_q2q3_ratio['Movie'][i]*100:.3}%", 
                   xy=(data_q2q3_ratio['Movie'][i]/2, i),
                   va = 'center', ha='center',fontsize=12, fontweight='light', fontfamily='serif',
                   color='white')

for i in data_q2q3_ratio.index:
    ax.annotate(f"{data_q2q3_ratio['TV Show'][i]*100:.3}%", 
                   xy=(data_q2q3_ratio['Movie'][i]+data_q2q3_ratio['TV Show'][i]/2, i),
                   va = 'center', ha='center',fontsize=12, fontweight='light', fontfamily='serif',
                   color='white')
    

fig.text(0.13, 0.93, 'Top 10 countries Movie & TV Show split', fontsize=15, fontweight='bold', fontfamily='serif')   
fig.text(0.131, 0.89, 'Percent Stacked Bar Chart', fontsize=12,fontfamily='serif')   

for s in ['top', 'left', 'right', 'bottom']:
    ax.spines[s].set_visible(False)
    
#ax.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, -0.06))

fig.text(0.75,0.9,"Movie", fontweight="bold", fontfamily='serif', fontsize=15, color='#b20710')
fig.text(0.81,0.9,"|", fontweight="bold", fontfamily='serif', fontsize=15, color='black')
fig.text(0.82,0.9,"TV Show", fontweight="bold", fontfamily='serif', fontsize=15, color='#221f1f')


fig.text(1.1, 0.93, 'Insight', fontsize=15, fontweight='bold', fontfamily='serif')

fig.text(1.1, 0.44, '''
Interestingly, Netflix in India
is made up nearly entirely of Movies. 

Bollywood is big business, and perhaps
the main focus of this industry is Movies
and not TV Shows.

South Korean Netflix on the other hand is 
almost entirely TV Shows.

The underlying resons for the difference 
in content must be due to market research
conducted by Netflix.
'''
         , fontsize=12, fontweight='light', fontfamily='serif')



import matplotlib.lines as lines
l1 = lines.Line2D([1, 1], [0, 1], transform=fig.transFigure, figure=fig,color='black',lw=0.2)
fig.lines.extend([l1])




ax.tick_params(axis='both', which='major', labelsize=12)
ax.tick_params(axis=u'both', which=u'both',length=0)

plt.show()

# %% [markdown]
# As I've noted in the insights on the plot, it is really interesting to see how the split of TV Shows and Movies varies by country.
#
# South Korea is dominated by TV Shows.
# Equally, India is dominated by Movies. This might be majorly due to Bollywood.
#
# # Ratings
#
# Let's briefly check out how ratings are distributed

# %%
order = pd.DataFrame(df.groupby('rating')['count'].sum().sort_values(ascending=False).reset_index())
rating_order = list(order['rating'])

# %%
mf = df.groupby('type')['rating'].value_counts().unstack().sort_index().fillna(0).astype(int)[rating_order]

movie = mf.loc['Movie']
tv = - mf.loc['TV Show']


fig, ax = plt.subplots(1,1, figsize=(12, 6))
ax.bar(movie.index, movie, width=0.5, color='#b20710', alpha=0.8, label='Movie')
ax.bar(tv.index, tv, width=0.5, color='#221f1f', alpha=0.8, label='TV Show')
#ax.set_ylim(-35, 50)

# Annotations
for i in tv.index:
    ax.annotate(f"{-tv[i]}", 
                   xy=(i, tv[i] - 60),
                   va = 'center', ha='center',fontweight='light', fontfamily='serif',
                   color='#4a4a4a')   

for i in movie.index:
    ax.annotate(f"{movie[i]}", 
                   xy=(i, movie[i] + 60),
                   va = 'center', ha='center',fontweight='light', fontfamily='serif',
                   color='#4a4a4a')
    
 

for s in ['top', 'left', 'right', 'bottom']:
    ax.spines[s].set_visible(False)

ax.set_xticklabels(mf.columns, fontfamily='serif')
ax.set_yticks([])    

ax.legend().set_visible(False)
fig.text(0.16, 1, 'Rating distribution by Film & TV Show', fontsize=15, fontweight='bold', fontfamily='serif')
fig.text(0.16, 0.89, 
'''We observe that some ratings are only applicable to Movies. 
The most common for both Movies & TV Shows are TV-MA and TV-14.
'''

, fontsize=12, fontweight='light', fontfamily='serif')


fig.text(0.755,0.924,"Movie", fontweight="bold", fontfamily='serif', fontsize=15, color='#b20710')
fig.text(0.815,0.924,"|", fontweight="bold", fontfamily='serif', fontsize=15, color='black')
fig.text(0.825,0.924,"TV Show", fontweight="bold", fontfamily='serif', fontsize=15, color='#221f1f')

plt.show()

# %% [markdown]
# # Content production trend over the time?

# %% [markdown]
# As we saw in the timeline at the start of this analysis, Netflix went global in 2016 - and it is extremely noticeable in this plot.
#
# The increase is Movie content is remarkable.

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
color = ["#b20710", "#221f1f"]

for i, mtv in enumerate(df['type'].value_counts().index):
    mtv_rel = df[df['type']==mtv]['year_added'].value_counts().sort_index()
    ax.plot(mtv_rel.index, mtv_rel, color=color[i], label=mtv)
    ax.fill_between(mtv_rel.index, 0, mtv_rel, color=color[i], alpha=0.9)
    
ax.yaxis.tick_right()
    
ax.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .7)

#ax.set_ylim(0, 50)
#ax.legend(loc='upper left')
for s in ['top', 'right','bottom','left']:
    ax.spines[s].set_visible(False)

ax.grid(False)

ax.set_xlim(2008,2020)
plt.xticks(np.arange(2008, 2021, 1))

fig.text(0.13, 0.85, 'Movies & TV Shows added over time', fontsize=15, fontweight='bold', fontfamily='serif')
fig.text(0.13, 0.59, 
'''We see a slow start for Netflix over several years. 
Things begin to pick up in 2015 and then there is a 
rapid increase from 2016.

It looks like content additions have slowed down in 2020, 
likely due to the COVID-19 pandemic.
'''

, fontsize=12, fontweight='light', fontfamily='serif')


fig.text(0.13,0.2,"Movie", fontweight="bold", fontfamily='serif', fontsize=15, color='#b20710')
fig.text(0.19,0.2,"|", fontweight="bold", fontfamily='serif', fontsize=15, color='black')
fig.text(0.2,0.2,"TV Show", fontweight="bold", fontfamily='serif', fontsize=15, color='#221f1f')

ax.tick_params(axis=u'both', which=u'both',length=0)

plt.show()

# %% [markdown]
# # Month-by-Month
#
# We've seen how content has increased over the years, but are there certain months that, on average, tend to enjoy more content being added?
#
# I'll show this in a couple of ways - a cumulative year view, and also as a radial plot...

# %%
month_order = ['January',
 'February',
 'March',
 'April',
 'May',
 'June',
 'July',
 'August',
 'September',
 'October',
 'November',
 'December']

df['month_name_added'] = pd.Categorical(df['month_name_added'], categories=month_order, ordered=True)

# %%
data_sub = df.groupby('type')['month_name_added'].value_counts().unstack().fillna(0).loc[['TV Show','Movie']].cumsum(axis=0).T

fig, ax = plt.subplots(1, 1, figsize=(12, 6))
color = ["#b20710", "#221f1f"]

for i, mtv in enumerate(df['type'].value_counts().index):
    mtv_rel = data_sub[mtv]
    ax.fill_between(mtv_rel.index, 0, mtv_rel, color=color[i], label=mtv,alpha=0.9)
    

    
ax.yaxis.tick_right()
    
ax.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .4)

#ax.set_ylim(0, 50)
#ax.legend(loc='upper left')
for s in ['top', 'right','bottom','left']:
    ax.spines[s].set_visible(False)

ax.grid(False)
ax.set_xticklabels(data_sub.index, fontfamily='serif', rotation=0)
ax.margins(x=0) # remove white spaces next to margins

#ax.set_xlim(2008,2020)
#plt.xticks(np.arange(2008, 2021, 1))

fig.text(0.13, 0.95, 'Content added by month [Cumulative Total]', fontsize=15, fontweight='bold', fontfamily='serif')
fig.text(0.13, 0.905, 
"The end & beginnings of each year seem to be Netflix's preference for adding content."

, fontsize=12, fontweight='light', fontfamily='serif')



fig.text(0.13,0.855,"Movie", fontweight="bold", fontfamily='serif', fontsize=15, color='#b20710')
fig.text(0.19,0.855,"|", fontweight="bold", fontfamily='serif', fontsize=15, color='black')
fig.text(0.2,0.855,"TV Show", fontweight="bold", fontfamily='serif', fontsize=15, color='#221f1f')


ax.tick_params(axis=u'both', which=u'both',length=0)

plt.show()

# %% [markdown]
# # Let us see how content is added across the year?
#
#
# By highlighting certain months, the reader's eye is drawn exactly where we want it.

# %%
data_sub2 = data_sub

data_sub2['Value'] = data_sub2['Movie'] + data_sub2['TV Show']
data_sub2 = data_sub2.reset_index()

df_polar = data_sub2.sort_values(by='month_name_added',ascending=False)


color_map = ['#221f1f' for _ in range(12)]
color_map[0] = color_map[11] =  '#b20710' # color highlight


# initialize the figure
plt.figure(figsize=(8,8))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 30
lowerLimit = 1
labelPadding = 30

# Compute max and min in the dataset
max = df_polar['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df_polar.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df_polar.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df_polar.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color=color_map,alpha=0.8
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df_polar["month_name_added"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, fontsize=10,fontfamily='serif',
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %% [markdown]
# Yes, December & January are definitely the best months for new content. Maybe Netflix knows that people have a lot of time off from work over this period and that it is a good time to reel people in?
#
# February is the worst - why might this be? Ideas welcomed!

# %%
# Genres
from sklearn.preprocessing import MultiLabelBinarizer 

import matplotlib.colors


# Custom colour map based on Netflix palette
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['#221f1f', '#b20710','#f5f5f1'])



def genre_heatmap(df, title):
    df['genre'] = df['listed_in'].apply(lambda x :  x.replace(' ,',',').replace(', ',',').split(',')) 
    Types = []
    for i in df['genre']: Types += i
    Types = set(Types)
    print("There are {} types in the Netflix {} Dataset".format(len(Types),title))    
    test = df['genre']
    mlb = MultiLabelBinarizer()
    res = pd.DataFrame(mlb.fit_transform(test), columns=mlb.classes_, index=test.index)
    corr = res.corr()
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    fig, ax = plt.subplots(figsize=(10, 7))
    fig.text(.54,.88,'Genre correlation', fontfamily='serif',fontweight='bold',fontsize=15)
    fig.text(.75,.665,
            '''
             It is interesting that Independant Movies
             tend to be Dramas. 
             
             Another observation is that 
             Internatinal Movies are rarely
             in the Children's genre.
             ''', fontfamily='serif',fontsize=12,ha='right')
    pl = sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, vmin=-.3, center=0, square=True, linewidths=2.5)
    
    plt.show()

# %%
df_tv = df[df["type"] == "TV Show"]
df_movies = df[df["type"] == "Movie"]


genre_heatmap(df_movies, 'Movie')
plt.show()
# Out:
# There are 20 types in the Netflix Movie Dataset

# %% [markdown]
# # Target Ages
#
# Does Netflix uniformly target certain demographics? Or does this vary by country?

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 12))

country_order2 = ['USA', 'India', 'UK', 'Canada', 'Japan', 'France', 'S. Korea', 'Spain',
       'Mexico', 'Turkey']

age_order = ['Kids','Older Kids','Teens','Adults']

sns.heatmap(df_heatmap.loc[age_order,country_order2],cmap=cmap,square=True, linewidth=2.5,cbar=False,
            annot=True,fmt='1.0%',vmax=.6,vmin=0.05,ax=ax,annot_kws={"fontsize":12})

ax.spines['top'].set_visible(True)


fig.text(.99, .725, 'Target ages proportion of total content by country', fontweight='bold', fontfamily='serif', fontsize=15,ha='right')   
fig.text(0.99, 0.7, 'Here we see interesting differences between countries. Most shows in India are targeted to teens, for instance.',ha='right', fontsize=12,fontfamily='serif') 

ax.set_yticklabels(ax.get_yticklabels(), fontfamily='serif', rotation = 0, fontsize=11)
ax.set_xticklabels(ax.get_xticklabels(), fontfamily='serif', rotation=90, fontsize=11)

ax.set_ylabel('')    
ax.set_xlabel('')
ax.tick_params(axis=u'both', which=u'both',length=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# Very interesting results.
#
# It is also interesting to note similarities between culturally similar countries - the US & UK are closey aligned with their Netflix target ages, yet vastly different to say, India or Japan!

# %%
us_ind = df[(df['first_country'] == 'USA') | (df['first_country'] == 'India' )]

data_sub = df.groupby('first_country')['year_added'].value_counts().unstack().fillna(0).loc[['USA','India']].cumsum(axis=0).T

# %% [markdown]
# # USA & India
#
# As the two largest content countries, it might be fun to compare the two

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
color = ['#221f1f', '#b20710','#f5f5f1']

for i, hs in enumerate(us_ind['first_country'].value_counts().index):
    hs_built = us_ind[us_ind['first_country']==hs]['year_added'].value_counts().sort_index()
    ax.plot(hs_built.index, hs_built, color=color[i], label=hs)
    #ax.fill_between(hs_built.index, 0, hs_built, color=color[i], alpha=0.4)
    ax.fill_between(hs_built.index, 0, hs_built, color=color[i], label=hs)
    

ax.set_ylim(0, 1000)
#ax.legend(loc='upper left')
for s in ['top', 'right']:
    ax.spines[s].set_visible(False)

ax.yaxis.tick_right()
    
ax.axhline(y = 0, color = 'black', linewidth = 1.3, alpha = .4)

#ax.set_ylim(0, 50)
#ax.legend(loc='upper left')
for s in ['top', 'right','bottom','left']:
    ax.spines[s].set_visible(False)

ax.grid(False)
ax.set_xticklabels(data_sub.index, fontfamily='serif', rotation=0)
ax.margins(x=0) # remove white spaces next to margins

ax.set_xlim(2008,2020)
plt.xticks(np.arange(2008, 2021, 1))

fig.text(0.13, 0.85, 'USA vs. India: When was content added?', fontsize=15, fontweight='bold', fontfamily='serif')
fig.text(0.13, 0.58, 
'''
We know from our work above that Netflix is dominated by the USA & India.
It would also be reasonable to assume that, since Netflix is an American
compnany, Netflix increased content first in the USA, before 
other nations. 

That is exactly what we see here; a slow and then rapid
increase in content for the USA, followed by Netflix 
being launched to the Indian market in 2016.'''

, fontsize=12, fontweight='light', fontfamily='serif')



fig.text(0.13,0.15,"India", fontweight="bold", fontfamily='serif', fontsize=15, color='#b20710')
fig.text(0.188,0.15,"|", fontweight="bold", fontfamily='serif', fontsize=15, color='black')
fig.text(0.198,0.15,"USA", fontweight="bold", fontfamily='serif', fontsize=15, color='#221f1f')


ax.tick_params(axis=u'both', which=u'both',length=0)


plt.show()

# %% [markdown]
# So the USA dominates the quantity of content produced.

# %% [markdown]
# # Lastly, we can view a wordcloud to get an overview of Netflix titles

# %%
from wordcloud import WordCloud
import random
from PIL import Image
import matplotlib

# Custom colour map based on Netflix palette
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['#221f1f', '#b20710'])

text = str(list(df['title'])).replace(',', '').replace('[', '').replace("'", '').replace(']', '').replace('.', '')


wordcloud = WordCloud(background_color = 'white', width = 500,  height = 200,colormap=cmap, max_words = 150).generate(text)

plt.figure( figsize=(5,5))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h2><strong>Important Insights </strong></h2>
# </div>

# %% [markdown]
# #### Amazon has the maximum content among the other OTTs both in terms of Movies and TV Shows.
# #### Netflix has the highest amount of Subscriber count.
# #### US, India and UK are the top producers of Content.
# #### Among the Top 3 producers, Netlfix content in India is targeted to Teens whereas for US and UK, it is targeted to Adults.
# #### December & January are definitely the best months for new content.
# #### Due to the Pandemic, the content additions took a slow down.

# %% [markdown]
# ## In addition to these, more Insights could be derived from the above analysis depending upon the area one is focussing on.
# ### For eg. If the user is interested in Family genre of Content, the above analysis can help him determine the OTT platform he can choose, which is Disney+

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h1><strong>THANK YOU!</strong></h1>
# </div>
